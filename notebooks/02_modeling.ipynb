# %% [markdown]
# # 02 Modeling\n\nReview clustering and embedding artifacts produced by the training pipeline.

# %%
from pathlib import Path\nimport pandas as pd\n\nanalysis = pd.read_parquet(Path('../data/processed/analysis.parquet'))\nprofiles = pd.read_csv(Path('../reports/tables/cluster_profiles.csv'))\nanalysis.head(), profiles.head()

# %%
analysis['cluster'].value_counts().sort_index()
