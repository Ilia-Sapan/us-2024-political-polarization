# %% [markdown]
# # 01 EDA\n\nExploratory analysis notebook for the cleaned CCES 2024 dataset.

# %%
from pathlib import Path\nimport pandas as pd\n\ncleaned_path = Path('../data/processed/cleaned.parquet')\ndf = pd.read_parquet(cleaned_path)\ndf.head()

# %%
df.shape, df.isna().mean().sort_values(ascending=False).head(20)
